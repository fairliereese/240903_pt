# %%
import pandas as pd
import numpy as np
import scipy.stats as st
import seaborn as sns
import sys
import os
import matplotlib.pyplot as plt
import swan_vis as swan
import yaml
from snakemake.io import expand
import cerberus
import pyranges as pr
import upsetplot

p = os.path.dirname(os.getcwd())
sys.path.append(p)

from scripts.utils import *
from scripts.vcf_utils import *
from scripts.plotting import *

# %%
config = load_config()
od = '../'

def proc_cfg(entry, od):
    entry = entry.replace('../../', '')
    entry = od+entry
    return entry

# %% [markdown]
# ## We want to get the dist. of distances between novel SSs and annotated SSs.
#
# Hopefully they are generally close

# %%
df = load_meta()
df = df.loc[~df['sample'].str.contains('_')]
df['lab_sample'] = df['lab_number_sample'].astype(str)+'_'+\
                      df['lab_sampleid'].astype(str)+'_'+\
                      df['cell_line_id'].astype(str)
df.columns
df = df[['cell_line_id', 'sample', 'hapmap_DNA_ID',
          'map_reads_assemblymap','lab_sample', 'population']].drop_duplicates()

temp_df = pd.read_csv('../snakemake/transcript_discovery_personal/cell_line_ids.txt', header=None, names=['cell_line_id'])

# make a 1000g cell line id col
df['cell_line_id_1000g'] = df.cell_line_id

inds = df.loc[~df.cell_line_id_1000g.isin(temp_df.cell_line_id.tolist())].index
df.loc[inds, 'cell_line_id_1000g'] = df.loc[inds, 'hapmap_DNA_ID']
len(df.index)

# limit to just those in 1000g
df = df.loc[df.cell_line_id_1000g.isin(temp_df.cell_line_id.tolist())]
assert len(df.index) == 30

# TODO bad sample that hasn't finished on espresso
# bad_samples = ['NA19328']
# df = df.loc[~df.cell_line_id_1000g.isin(bad_samples)]

hap = ['hap1', 'hap2']

meta_df = df.copy(deep=True)

# %%
file = proc_cfg(config['lr']['td_personal']['sqanti']['sj_summary'],od)
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['detected'] = True

# 1.5 only novel sss
temp = df.loc[(df.start_site_novelty=='novel')|(df.end_site_category=='novel')]

# only keep unique novel sjs
temp[['Chromosome', 'Strand', 'Start', 'End']] = temp.sj_id.str.split('_', expand=True)
temp = temp[['Chromosome', 'Strand', 'Start', 'End', 'sj_id', 
             'start_site_novelty', 'end_site_category', 'cell_line_id']].drop_duplicates()

temp.Start = temp.Start.astype(int)
temp.End = temp.End.astype(int)
assert len(temp.loc[temp.Start>temp.End])==0

# melt to 5' and 3'
temp = temp.melt(id_vars=['Chromosome', 'Strand', 'sj_id',
                          'start_site_novelty', 'end_site_category', 'cell_line_id'],
                 value_vars=['Start', 'End'])
temp['sj_loc'] = ''


temp.loc[temp.variable=='Start', 'sj_loc'] = 'start'
temp.loc[temp.variable=='End', 'sj_loc'] = 'end'

temp['novelty_category'] = ''
temp.loc[temp.variable=='Start', 'novelty_category'] = temp.loc[temp.variable=='Start', 'start_site_novelty']
temp.loc[temp.variable=='End', 'novelty_category'] = temp.loc[temp.variable=='End', 'end_site_category']

# only get the novel ones now
temp = temp.loc[temp.novelty_category=='novel']

temp.rename({'value':'Start'}, axis=1, inplace=True)
# need to verify that this is working using like one motif or something make
# sure I don't have off-by-one errors
# verified
temp['Start'] = temp.Start-2
temp['End'] = temp.Start+1

# verified
temp.loc[temp.sj_loc=='start', 'Start'] = temp.loc[temp.sj_loc=='start', 'Start']-0
temp.loc[temp.sj_loc=='start', 'End'] = temp.loc[temp.sj_loc=='start', 'End']+0


temp.loc[temp.sj_loc=='end', 'End'] = temp.loc[temp.sj_loc=='end', 'End']+2
temp.loc[temp.sj_loc=='end', 'Start'] = temp.loc[temp.sj_loc=='end', 'Start']+2

# %%
nov_ss_df = temp.copy(deep=True)
nov_ss_df.head()
# Out:
#    Chromosome Strand                     sj_id start_site_novelty  \
# 0  GL000195.1      -  GL000195.1_-_49120_86517              novel
# 1       chr17      -   chr17_-_1821508_1827860              novel
# 2       chr17      -   chr17_-_1821512_1827860              novel
# 3       chr17      -   chr17_-_1823205_1827860              novel
# 4       chr17      -   chr17_-_1825231_1827860              novel
#
#   end_site_category cell_line_id variable    Start sj_loc novelty_category  \
# 0             known      NA12273    Start    49118  start            novel
# 1             known      NA12273    Start  1821506  start            novel
# 2             known      NA12273    Start  1821510  start            novel
# 3             known      NA12273    Start  1823203  start            novel
# 4             known      NA12273    Start  1825229  start            novel
#
#        End
# 0    49119
# 1  1821507
# 2  1821511
# 3  1823204
# 4  1825230

# %%
# temp = pr.PyRanges(temp)
# temp.to_bed('test_novel_ss.bed')

# %%
# get annotated (v47) sss
gtf_file = proc_cfg(config['ref']['gtf'], od)

# read in ref. gtf and get SJs from there
temp = pr.read_gtf(gtf_file)

# get the introns
temp = temp.features.introns()
temp = temp.df

temp.Start = temp.Start.astype(int)
temp.End = temp.End.astype(int)
assert len(temp.loc[temp.Start>temp.End])==0

# melt to 5' and 3'
temp = temp.melt(id_vars=['Chromosome', 'Strand'],
                 value_vars=['Start', 'End'])
temp['sj_loc'] = ''
temp.loc[temp.variable=='Start', 'sj_loc'] = 'start'
temp.loc[temp.variable=='End', 'sj_loc'] = 'end'

temp.rename({'value':'Start'}, axis=1, inplace=True)

temp['Start'] = temp.Start-2
temp['End'] = temp.Start+1

# need to verify
temp.loc[temp.sj_loc=='start', 'Start'] = temp.loc[temp.sj_loc=='start', 'Start']+1
temp.loc[temp.sj_loc=='start', 'End'] = temp.loc[temp.sj_loc=='start', 'End']+1


temp.loc[temp.sj_loc=='end', 'End'] = temp.loc[temp.sj_loc=='end', 'End']+2
temp.loc[temp.sj_loc=='end', 'Start'] = temp.loc[temp.sj_loc=='end', 'Start']+2


temp = pr.PyRanges(temp)

# %%
temp.to_bed('test_v47_ss.bed')

# %%
nov_ss_df = pr.PyRanges(nov_ss_df)

# %%
# get closest entry from novel sss to known sss
df = nov_ss_df.nearest(temp, strandedness=False)
df = df.df

# %%
# what % of these are w/i 12 bp of an annotated one
assert len(df.loc[df.Distance<0]) == 0 # no neg. dists
n_num = len(df.loc[df.Distance<=12].index)
n = len(df.index)
print(f'{(n_num/n)*100:.2f}% of novel personalized haplotype SJs are w/i 12bp of an annotated one')
# Out:
# 8.17% of novel personalized haplotype SJs are w/i 12bp of an annotated one

# %%
# plot dist. 
sns.displot(df,
            x='Distance',
            kind='kde')
# Out:
# 360601

# %%
df.loc[df.Distance<12]
# Out:
#         Chromosome Strand                       sj_id start_site_novelty  \
# 203     GL000194.1      -  GL000194.1_-_112851_114981              known
# 204     GL000194.1      -  GL000194.1_-_112851_114981              known
# 205     GL000194.1      -  GL000194.1_-_112851_114981              known
# 206     GL000194.1      -  GL000194.1_-_112851_114981              known
# 207     GL000194.1      -  GL000194.1_-_112851_114981              known
# ...            ...    ...                         ...                ...
# 360421        chrY      +    chrY_+_20575888_20579616              known
# 360424        chrY      +    chrY_+_20579692_20582591              known
# 360425        chrY      +    chrY_+_20579692_20582591              known
# 360426        chrY      +    chrY_+_20579692_20582591              known
# 360427        chrY      +    chrY_+_20579692_20582591              known
#
#        end_site_category cell_line_id variable     Start sj_loc  \
# 203                novel      NA12778      End    114981    end
# 204                novel      HG04216      End    114981    end
# 205                novel      HG01975      End    114981    end
# 206                novel      HG03729      End    114981    end
# 207                novel      HG04217      End    114981    end
# ...                  ...          ...      ...       ...    ...
# 360421             novel      NA19307      End  20579616    end
# 360424             novel      HG00621      End  20582591    end
# 360425             novel      HG01952      End  20582591    end
# 360426             novel      NA18486      End  20582591    end
# 360427             novel      NA19307      End  20582591    end
#
#        novelty_category       End Strand_b variable_b   Start_b sj_loc_b  \
# 203               novel    114982        -        End    114985      end
# 204               novel    114982        -        End    114985      end
# 205               novel    114982        -        End    114985      end
# 206               novel    114982        -        End    114985      end
# 207               novel    114982        -        End    114985      end
# ...                 ...       ...      ...        ...       ...      ...
# 360421            novel  20579617        +        End  20579607      end
# 360424            novel  20582592        +        End  20582589      end
# 360425            novel  20582592        +        End  20582589      end
# 360426            novel  20582592        +        End  20582589      end
# 360427            novel  20582592        +        End  20582589      end
#
#            End_b  Distance
# 203       114986         4
# 204       114986         4
# 205       114986         4
# 206       114986         4
# 207       114986         4
# ...          ...       ...
# 360421  20579608         9
# 360424  20582590         2
# 360425  20582590         2
# 360426  20582590         2
# 360427  20582590         2
#
# [28173 rows x 17 columns]

# %% [markdown]
# ## Try specifically subsetting on the SJs that are exclusively found in hap1/hap2?

# %%
file = proc_cfg(config['lr']['td_personal']['sqanti']['sj_summary'],od)
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
# dedupe w/ sqanti genome cause no one cares
df = df.drop(['sqanti_genome', 'splice_motif', 'canonical'], axis=1)
print(len(df.index))
df = df.drop_duplicates()
print(len(df.index))
# Out:
# 24934518
# 8311506

# %%
# # try just w/ one cell line for now
# df = df.loc[df.cell_line_id=='NA12273']
# df_back = df.copy(deep=True)

# %%
df = df_back.copy(deep=True)
df.head()
# Out:
#                         sj_id splice_motif  canonical junction_novelty  \
# 0    KI270741.1_+_44470_47849         GTAG  canonical            known
# 1    KI270741.1_+_48008_52058         GTAG  canonical            known
# 2   KI270741.1_+_52137_130639         GTAG  canonical            known
# 3    KI270741.1_+_44470_47948         GTAG  canonical            known
# 4  GL000224.1_+_102592_105978         GTAG  canonical            known
#
#   start_site_novelty end_site_category cell_line_id map_genome
# 0              known             known      NA12273       hg38
# 1              known             known      NA12273       hg38
# 2              known             known      NA12273       hg38
# 3              known             known      NA12273       hg38
# 4              known             known      NA12273       hg38

# %%
# TODO put me in coach
# # 1. filter for sjs w/ at least one novel ss 
# df = df.loc[(df.start_site_novelty=='novel')|(df.end_site_category=='novel')]

# %%
# melt to 5' and 3'
df[['Chromosome', 'Strand', 'Start', 'End']] = df.sj_id.str.split('_', expand=True)
df.tail()
# Out:
#                                sj_id splice_motif      canonical  \
# 8784437   chr2_-_225040714_225041288         GTAG      canonical
# 8784718   chr2_-_231513633_231514081         ATAG  non_canonical
# 8800830  chr10_-_132324374_132331650         GTAG      canonical
# 8800831  chr10_-_132331529_132331650         GTAG      canonical
# 8802477    chr16_+_29482592_29486512         GTAG      canonical
#
#         junction_novelty start_site_novelty end_site_category cell_line_id  \
# 8784437            novel              novel             novel      NA12273
# 8784718            known              known             known      NA12273
# 8800830            novel              known             novel      NA12273
# 8800831            novel              novel             novel      NA12273
# 8802477            novel              novel             known      NA12273
#
#         map_genome Chromosome Strand      Start        End
# 8784437       hap1       chr2      -  225040714  225041288
# 8784718       hap1       chr2      -  231513633  231514081
# 8800830       hap1      chr10      -  132324374  132331650
# 8800831       hap1      chr10      -  132331529  132331650
# 8802477       hap1      chr16      +   29482592   29486512

# %%
# # TODO remove
# df['ss_1_id'] = df.sj_id.str.rsplit('_', n=1, expand=True)[0]
# df['ss_2_id'] = df.sj_id.str.rsplit('_', n=2, expand=True)[0]+'_'+df.sj_id.str.rsplit('_', n=1, expand=True)[1]

# df['n_ss_1'] = df.groupby('ss_1_id')['sj_id'].transform('nunique')
# df['n_ss_2'] = df.groupby('ss_2_id')['sj_id'].transform('nunique')
# df.loc[df.n_ss_1>1].sort_values(by='ss_1_id').head()

# %%
df = df.melt(id_vars=['Chromosome', 'Strand', 'map_genome',
                      'start_site_novelty', 'end_site_category', 'cell_line_id'],
                 value_vars=['Start', 'End'])
df['sj_loc'] = ''
df['detected'] = True


df.loc[df.variable=='Start', 'sj_loc'] = 'start'
df.loc[df.variable=='End', 'sj_loc'] = 'end'

df['novelty_category'] = ''
df.loc[df.variable=='Start', 'novelty_category'] = df.loc[df.variable=='Start', 'start_site_novelty']
df.loc[df.variable=='End', 'novelty_category'] = df.loc[df.variable=='End', 'end_site_category']

# only get the novel ones now
df = df.loc[df.novelty_category=='novel']

df.rename({'value':'Start'}, axis=1, inplace=True)

# create id for each ss
df['ss_id'] = 'ss_'+\
                df.sj_loc+'_'+\
                df.Chromosome+'_'+\
                df.Strand+'_'+\
                df.Start.astype(str)

df = df[['ss_id', 'cell_line_id', 'map_genome', 'detected']]

# check for sss that originated from different sjs
assert len(df.loc[df.ss_id.duplicated()]) > 0

# then dedupe and pivot
df = df.drop_duplicates()
df = df.pivot(index=['ss_id', 'cell_line_id'], 
                columns=['map_genome'],
                values=['detected'])

# flatten
df.columns = df.columns.get_level_values(1)
df.columns.name = None

# reset index to make it a flat DataFrame
df = df.reset_index()

# fill missing values with False
df = df.fillna(False)

# %%
df.head()

# %%
df.loc[df.ss_id=='ss_start_chr17_+_5426072']
# Out:
#                          ss_id cell_line_id  hap1  hap2  hg38
# 5156  ss_start_chr17_+_5426072      NA12273  True  True  True

# %%
df['ss_count'] = df.groupby('ss_id')['map_genome'].transform('count')
df.loc[df.ss_count>3].head()
# Out:
#     Chromosome Strand map_genome start_site_novelty end_site_category  \
# 430      chr17      +       hg38              novel             known
# 431      chr17      +       hg38              novel             known
# 779      chr17      -       hg38              novel             known
# 781      chr17      -       hg38              novel             known
# 981      chr17      +       hg38              novel             novel
#
#     cell_line_id variable     Start sj_loc  detected novelty_category  \
# 430      NA12273    Start   5426072  start      True            novel
# 431      NA12273    Start   5426072  start      True            novel
# 779      NA12273    Start   8174262  start      True            novel
# 781      NA12273    Start   8174262  start      True            novel
# 981      NA12273    Start  16381116  start      True            novel
#
#                          ss_id  ss_count
# 430   ss_start_chr17_+_5426072         6
# 431   ss_start_chr17_+_5426072         6
# 779   ss_start_chr17_-_8174262         6
# 781   ss_start_chr17_-_8174262         6
# 981  ss_start_chr17_+_16381116        12

# %%
# # take max. of detection for the same ss id and map genome (in case one side of a splice junction was part of a different
# # sj in some other context)
# assert len(df.loc[df.ss_id.duplicated()]) > 0
# print(df.loc[df.ss_id.duplicated(keep=False), 'ss_id'].head())
# df = df.groupby(['ss_id', 'cell_line_id']).max().reset_index()
# assert len(df.index) == len(df.drop_duplicates().index)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-204-3bee9efaf0aa> in <module>
#       1 # take max. of detection for the same ss id and map genome (in case one side of a splice junction was part of a different
#       2 # sj in some other context)
# ----> 3 assert len(df.loc[df.ss_id.duplicated()]) > 0
#       4 print(df.loc[df.ss_id.duplicated(keep=False), 'ss_id'].head())
#       5 df = df.groupby(['ss_id', 'cell_line_id']).max().reset_index()
#
# AssertionError:

# %%
# 1. get those that are detected uniquely in hap1/2 
# (ie those not in hg38)
df = df.loc[(df.hg38==False)&
                ((df.hap1+df.hap2)>0)]

# %%
# now check one of these guys in the og df
df.head()
df.loc[df.ss_id.str.contains('97738675')]
# Out:
# Empty DataFrame
# Columns: [ss_id, cell_line_id, hap1, hap2, hg38]
# Index: []

# %%
df_back.loc[df_back.sj_id.str.contains('97742567')]
# Out:
#                              sj_id splice_motif  canonical junction_novelty  \
# 8361277  chr10_+_97738675_97742567         GTAG  canonical            novel
# 8625246  chr10_+_97738675_97742567         GTAG  canonical            novel
#
#         start_site_novelty end_site_category cell_line_id map_genome
# 8361277              known             novel      NA12273       hap2
# 8625246              known             novel      NA12273       hap1

# %%
# 1.5 only novel sss
temp = df.loc[(df.start_site_novelty=='novel')|(df.end_site_category=='novel')]

# %%
# temp_back = temp.copy(deep=True)

# %%
temp = temp_back.copy(deep=True)

# %%
temp[['Chromosome', 'Strand', 'Start', 'End']] = temp.sj_id.str.split('_', expand=True)

temp.Start = temp.Start.astype(int)
temp.End = temp.End.astype(int)
assert len(temp.loc[temp.Start>temp.End])==0

# melt to 5' and 3'
temp = temp.melt(id_vars=['Chromosome', 'Strand', 'sj_id',
                          'start_site_novelty', 'end_site_category', 'cell_line_id',
                          'map_genome', 'sqanti_genome'],
                 value_vars=['Start', 'End'])
temp['sj_loc'] = ''
temp['detected'] = True

# %%
temp.loc[temp.variable=='Start', 'sj_loc'] = 'start'
temp.loc[temp.variable=='End', 'sj_loc'] = 'end'

temp['novelty_category'] = ''
temp.loc[temp.variable=='Start', 'novelty_category'] = temp.loc[temp.variable=='Start', 'start_site_novelty']
temp.loc[temp.variable=='End', 'novelty_category'] = temp.loc[temp.variable=='End', 'end_site_category']

# only get the novel ones now
temp = temp.loc[temp.novelty_category=='novel']

temp.rename({'value':'Start'}, axis=1, inplace=True)

# %%
# create id for each ss
temp['ss_id'] = 'ss_'+\
                temp.sj_loc+'_'+\
                temp.Chromosome+'_'+\
                temp.Strand+'_'+\
                temp.Start.astype(str)

# %%
temp = temp[['ss_id', 'sj_id', 'cell_line_id', 'map_genome', 'detected']]
temp = temp.drop_duplicates()
temp = temp.pivot(index=['ss_id', 'cell_line_id', 'sj_id'], 
                columns=['map_genome'],
                values=['detected'])

# flatten
temp.columns = temp.columns.get_level_values(1)
temp.columns.name = None

# reset index to make it a flat DataFrame
temp = temp.reset_index()

# fill missing values with False
temp = temp.fillna(False)

# %%
len(temp.loc[temp[['hap1', 'hap2', 'hg38']].sum(axis=1)>1])
# Out:
# 8333

# %%
# kept in sj_id just to do some checking back in parent dataframe to make sure I'm not
# doing anything insane
temp_back.loc[(temp_back.sj_id=='KI270726.1_+_26127_26229')&(temp_back.cell_line_id=='HG02261')]
# Out:
#                              sj_id splice_motif  canonical junction_novelty  \
# 21436766  KI270726.1_+_26127_26229         GTAG  canonical            novel
# 21540547  KI270726.1_+_26127_26229         GTAG  canonical            novel
# 21644328  KI270726.1_+_26127_26229         GTAG  canonical            novel
#
#          start_site_novelty end_site_category cell_line_id map_genome  \
# 21436766              novel             novel      HG02261       hap1
# 21540547              novel             novel      HG02261       hap1
# 21644328              novel             novel      HG02261       hap1
#
#          sqanti_genome  detected
# 21436766          hg38      True
# 21540547          hap2      True
# 21644328          hap1      True

# %%
# 1. get those that are detected uniquely in hap1/2 
# (ie those not in hg38)
temp = temp.loc[(temp.hg38==False)&
                ((temp.hap1+temp.hap2)>0)]

# %%
# need to verify that this is working using like one motif or something make
# sure I don't have off-by-one errors
# verified
temp['Start'] = temp.Start-2
temp['End'] = temp.Start+1

# verified
temp.loc[temp.sj_loc=='start', 'Start'] = temp.loc[temp.sj_loc=='start', 'Start']-0
temp.loc[temp.sj_loc=='start', 'End'] = temp.loc[temp.sj_loc=='start', 'End']+0


temp.loc[temp.sj_loc=='end', 'End'] = temp.loc[temp.sj_loc=='end', 'End']+2
temp.loc[temp.sj_loc=='end', 'Start'] = temp.loc[temp.sj_loc=='end', 'Start']+2

# %%
file = proc_cfg(config['lr']['td_personal']['sqanti']['sj_summary'],od)
df = pd.read_csv(file)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['detected'] = True

# 1.5 only novel sss
temp = df.loc[(df.start_site_novelty=='novel')|(df.end_site_category=='novel')]

# only keep unique novel sjs
temp[['Chromosome', 'Strand', 'Start', 'End']] = temp.sj_id.str.split('_', expand=True)
temp = temp[['Chromosome', 'Strand', 'Start', 'End', 'sj_id', 
             'start_site_novelty', 'end_site_category', 'cell_line_id']].drop_duplicates()

temp.Start = temp.Start.astype(int)
temp.End = temp.End.astype(int)
assert len(temp.loc[temp.Start>temp.End])==0

# melt to 5' and 3'
temp = temp.melt(id_vars=['Chromosome', 'Strand', 'sj_id',
                          'start_site_novelty', 'end_site_category', 'cell_line_id'],
                 value_vars=['Start', 'End'])
temp['sj_loc'] = ''


temp.loc[temp.variable=='Start', 'sj_loc'] = 'start'
temp.loc[temp.variable=='End', 'sj_loc'] = 'end'

temp['novelty_category'] = ''
temp.loc[temp.variable=='Start', 'novelty_category'] = temp.loc[temp.variable=='Start', 'start_site_novelty']
temp.loc[temp.variable=='End', 'novelty_category'] = temp.loc[temp.variable=='End', 'end_site_category']

# only get the novel ones now
temp = temp.loc[temp.novelty_category=='novel']

temp.rename({'value':'Start'}, axis=1, inplace=True)
# need to verify that this is working using like one motif or something make
# sure I don't have off-by-one errors
# verified
temp['Start'] = temp.Start-2
temp['End'] = temp.Start+1

# verified
temp.loc[temp.sj_loc=='start', 'Start'] = temp.loc[temp.sj_loc=='start', 'Start']-0
temp.loc[temp.sj_loc=='start', 'End'] = temp.loc[temp.sj_loc=='start', 'End']+0


temp.loc[temp.sj_loc=='end', 'End'] = temp.loc[temp.sj_loc=='end', 'End']+2
temp.loc[temp.sj_loc=='end', 'Start'] = temp.loc[temp.sj_loc=='end', 'Start']+2
# Out:
#                            sj_id cell_line_id   hap1   hap2   hg38  n_novel_sj
# 67      GL000194.1_-_53893_55445      HG03729  False   True  False       15825
# 68      GL000194.1_-_53893_55445      HG04217  False   True  False       15175
# 73      GL000194.1_-_54956_55445      HG04217  False   True  False       15175
# 470     KI270726.1_+_26127_26229      HG02261   True  False  False       19818
# 515  chr10_+_100987611_100989643      NA19307   True   True  False       11472

# %%
# # 1.5 only novel sss
# temp = df.loc[(df.start_site_novelty=='novel')|(df.end_site_category=='novel')]

# # only keep unique novel sjs
# temp[['Chromosome', 'Strand', 'Start', 'End']] = temp.sj_id.str.split('_', expand=True)
# temp = temp[['Chromosome', 'Strand', 'Start', 'End', 'sj_id', 
#              'start_site_novelty', 'end_site_category', 'cell_line_id']].drop_duplicates()

# temp.Start = temp.Start.astype(int)
# temp.End = temp.End.astype(int)
# assert len(temp.loc[temp.Start>temp.End])==0

# # melt to 5' and 3'
# temp = temp.melt(id_vars=['Chromosome', 'Strand', 'sj_id',
#                           'start_site_novelty', 'end_site_category', 'cell_line_id'],
#                  value_vars=['Start', 'End'])
# temp['sj_loc'] = ''


# temp.loc[temp.variable=='Start', 'sj_loc'] = 'start'
# temp.loc[temp.variable=='End', 'sj_loc'] = 'end'

# temp['novelty_category'] = ''
# temp.loc[temp.variable=='Start', 'novelty_category'] = temp.loc[temp.variable=='Start', 'start_site_novelty']
# temp.loc[temp.variable=='End', 'novelty_category'] = temp.loc[temp.variable=='End', 'end_site_category']

# # only get the novel ones now
# temp = temp.loc[temp.novelty_category=='novel']

# temp.rename({'value':'Start'}, axis=1, inplace=True)
# # need to verify that this is working using like one motif or something make
# # sure I don't have off-by-one errors
# # verified
# temp['Start'] = temp.Start-2
# temp['End'] = temp.Start+1

# # verified
# temp.loc[temp.sj_loc=='start', 'Start'] = temp.loc[temp.sj_loc=='start', 'Start']-0
# temp.loc[temp.sj_loc=='start', 'End'] = temp.loc[temp.sj_loc=='start', 'End']+0


# temp.loc[temp.sj_loc=='end', 'End'] = temp.loc[temp.sj_loc=='end', 'End']+2
# temp.loc[temp.sj_loc=='end', 'Start'] = temp.loc[temp.sj_loc=='end', 'Start']+2
